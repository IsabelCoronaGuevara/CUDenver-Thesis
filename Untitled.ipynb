# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

grades_exam1 = [86 , 101.5 , 87 , 50 , 97 , 84 , 81.5 , 86.5 , 91 , 87.5 , 98 , 
  101 , 67.5 , 83 , 104 , 69.5 , 98.5 , 98 , 98 , 103 , 40 , 93.5 , 
  77 , 96.5 , 80.5 , 78 , 92 , 65.5]

# %%
grades_exam2 = [100, 104, 22, 100.5, 103.5, 101.5, 49, 82.5, 103, 103.5, 
          84.5, 75, 83, 100, 83.5, 83, 61, 30.5, 79.5, 57,
          93, 74.5, 76, 81, 60.5, 22, 91]

# %%
grades_exam3 = [68, 78.5, 98.5, 58, 62, 95, 88, 55.5, 92.5, 96.5, 66, 98.5, 27.5, 
                94.5, 85.5, 76.5, 78, 87.5, 70.5, 72, 75, 
               103, 103.5, 100.5, 101.5, 103,0]

# %%
np.mean(np.array(grades_exam3)+2)
# Out:
# 81.0925925925926

# %%
np.median(grades_exam3)
# Out:
# 78.0

# %%
plt.hist(grades_exam3, bins = 10);

# %%
 sns.distplot(np.array(grades_exam3)+2, hist=True, kde=True, 
             bins=10, color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4});
# Out:
# /var/folders/6l/nmzh70mx64s3ykd63cty8kg80000gn/T/ipykernel_28398/807930196.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.array(grades_exam3)+2, hist=True, kde=True,

# %%
# ?sns.displot
