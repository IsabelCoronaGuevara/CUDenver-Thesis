# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

grades_exam1 = [86 , 101.5 , 87 , 50 , 97 , 84 , 81.5 , 86.5 , 91 , 87.5 , 98 , 
  101 , 67.5 , 83 , 104 , 69.5 , 98.5 , 98 , 98 , 103 , 40 , 93.5 , 
  77 , 96.5 , 80.5 , 78 , 92 , 65.5]

# %%
final_grades = np.array([82.79,
91.01,
16.54,
90.92,
77.48,
77.73,
100.33,
84.94,
75.01,
76.15,
51.76,
42.70,
90.68,
96.01,
101.37,
90.24,
43.50,
98.67,
66.71,
99.76,
79.91,
63.62,
100.57,
87.88,
78.83,
92.89,
76.93,
77.55,
81.57,
60.34,
77.10])

# %%
letter_grades = [
'B-',
'A-',
'F',
'A-',
'C+',
'C+',
'A',
'B',
'C',
'C',
'F',
'F',
'A-',
'A',
'A',
'A-',
'F',
'A',
'D',
'A',
'B+',
'D',
'A',
'B+',
'C+',
'A-',
'C',
'C+',
'B-',
'D',
'C+']

# %%
letter_grades.count('F')
# Out:
# 4

# %%
plt.hist(letter_grades)
# Out:
# (array([2., 5., 4., 5., 0., 6., 1., 3., 3., 2.]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. , 4.8, 5.6, 6.4, 7.2, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
# ?plt.bar

# %%
grades_exam2 = [100, 104, 22, 100.5, 103.5, 101.5, 49, 82.5, 103, 103.5, 
          84.5, 75, 83, 100, 83.5, 83, 61, 30.5, 79.5, 57,
          93, 74.5, 76, 81, 60.5, 22, 91]

# %%
grades_exam3 = [68, 78.5, 98.5, 58, 62, 95, 88, 55.5, 92.5, 96.5, 66, 98.5, 27.5, 
                94.5, 85.5, 76.5, 78, 87.5, 70.5, 72, 75, 
               103, 103.5, 100.5, 101.5, 103,0]

# %%
grades_final = np.array([108, 101, 97, 117.5, 114, 120, 115, 108.5, 83.5, 87.5, 57, 
                57.5, 115, 110.5, 91.5, 89.5, 62, 102.5, 47, 88, 30.5, 78.5, 102, 76.5, 103, 69, 59, 80])

# %%
np.mean(100*grades_final/120)
# Out:
# 73.54166666666666

# %%
np.std(100*grades_final/120)
# Out:
# 19.487639804725717

# %%
np.median(100*grades_final/120)
# Out:
# 75.41666666666666

# %%
plt.hist(grades_final, bins = 10);

# %%
 sns.distplot(final_grades, hist=True, kde=True, 
             bins=10, color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4});
# Out:
# /var/folders/6l/nmzh70mx64s3ykd63cty8kg80000gn/T/ipykernel_46400/335760823.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(final_grades, hist=True, kde=True,

# %%
# ?sns.displot
