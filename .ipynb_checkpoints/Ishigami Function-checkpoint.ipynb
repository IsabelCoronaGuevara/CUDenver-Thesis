# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import scipy.special as special
from scipy.special import legendre
import math
from itertools import product
from scipy.special import gamma
import sys
import pandas as pd
import seaborn as sns
sns.set()
from PC_VRVM import *
from AFVB_PCE import *

# %%
### Making a Basis function
### This will be inputed into the ChaosModel function

def basis(Z):
    """
    input:
    
    return:
    
    """
    d = 3
    max_deg = 8
    N = Z.shape[0] # Number of samples
    n = int(math.factorial(d + max_deg)/(math.factorial(d)*math.factorial(max_deg)))
    Phi = np.zeros((N, n))
    
    #########################################################
    #### Compute multivariate orthonormal polynomial Phi ####
    #########################################################
    def multivariate_pce_index(d, max_deg):
        """
        Generate all the d-dimensional polynomial indices with the 
        constraint that the sum of the indexes is <= max_deg
    
        input:
        d: int, number of random variables
        max_deg: int, the max degree allowed
    
        return: 
        2d array with shape[1] equal to d, the multivariate indices
        """
        maxRange = max_deg*np.ones(d, dtype = 'int')
        index = np.array([i for i in product(*(range(i + 1) for i in maxRange)) if sum(i) <= max_deg])
        return index
    
    index = multivariate_pce_index(d, max_deg)

    for i in range(n):
        Phi[:,i] =  math.sqrt(2*index[i][0]+1)*math.sqrt(2*index[i][1]+1)*math.sqrt(2*index[i][2]+1) \
                   *legendre(index[i][0])(Z[:,0]) \
                   *legendre(index[i][1])(Z[:,1]) \
                   *legendre(index[i][2])(Z[:,2])
    
    return Phi

# %% [markdown]
# ## AFVB-PCE (Bhattacharyya) - Ishigami Function

# %%
################
#### Inputs ####
################
N = 35 # N --> number of samples
d = 3  # d --> number of random variables
p = 8  # p --> degree of PCE polynomial
n = int(math.factorial(d + p)/(math.factorial(d)*math.factorial(p))) # n --> Number of terms in the PCE expansion
# A_0 and B_0 --> the parameters of the Gamma distribution in the joint Gaussian-Gamma 
# distribution used to express the prior
A_0 = 0.1 
B_0 = 0.0001 
# C_0 and D_0 --> the paramters of the Gamma distribution in the distribution of the hyper-prior
C_0 = 0.1
D_0 = 0.0001 
T_ell = 0.001 # T_ell --> threshold value for the VLB (for the error e_ell) in percent
e = 1000 # e --> ddjustable parameter for the threshold value

# %%
np.random.seed(123)

data={'Xi':np.random.uniform(-1,1,size=(N,d))}
data['Y'] = np.sin(np.pi*data['Xi'][:,0]) + 7*(np.sin(np.pi*data['Xi'][:,1]))**2 + 0.1*(np.pi*data['Xi'][:,2])**4*np.sin(np.pi*data['Xi'][:,0])

params = {'A_0' : A_0, 'B_0': B_0, 'C_0': C_0, 'D_0': D_0}
mod = AFVB_PCE(params, p, data, basis)
Phi_hat, a_hat, Phi_full, a_full, active_cols = mod.algorithm(T_ell, e)
# Out:
# 1 (35, 165) -244.86471462611888
# 2 (35, 163) -242.2891811101439
# 3 (35, 155) -232.0104742173217
# 4 (35, 129) -198.64588640771234
# 5 (35, 102) -164.0381629359199
# 6 (35, 74) -128.1834008346784
# 7 (35, 54) -102.59977583914754
# 8 (35, 44) -89.82052246150128
# 9 (35, 37) -80.88615902208102
# 10 (35, 31) -73.23505732455055
# 11 (35, 27) -68.13966286748342
# 12 (35, 24) -64.32334524761771
# 13 (35, 22) -61.7829701823181
# 14 (35, 21) -60.5139936457115
# 15 (35, 19) -57.98018404231981
# 16 (35, 18) -56.71653661712608
# 17 (35, 16) -54.190917853994335
# 18 (35, 15) -52.930018950135704
# 19 (35, 14) -51.672745026858614
# 20 (35, 13) -50.41940459608801
# 21 (35, 12) -51.65156214144115
# 22 (35, 11) -63.743098233645696
# 23 (35, 10) -67.650436918178
# 24 (35, 9) -70.88681261112288
# 25 (35, 8) -72.09373320929404
# 26 (35, 7) -73.69396799311679
# 27 (35, 6) -72.72427845260793
# 28 (35, 5) -74.59872925840416
# 29 (35, 4) -89.2918437580275
# 30 (35, 3) -94.57927420089712
# 31 (35, 2) -104.51351335006652
# 1 (35, 165) -244.86471462611888
# 2 (35, 163) -242.2891811101439
# 3 (35, 155) -232.0104742173217
# 4 (35, 129) -198.64588640771234
# 5 (35, 102) -164.0381629359199
# 6 (35, 74) -128.1834008346784
# 7 (35, 54) -102.59977583914754
# 8 (35, 44) -89.82052246150128
# 9 (35, 37) -80.88615902208102
# 10 (35, 31) -73.23505732455055
# 11 (35, 27) -68.13966286748342
# 12 (35, 24) -64.32334524761771
# 13 (35, 22) -61.7829701823181
# 14 (35, 21) -60.5139936457115
# 15 (35, 19) -57.98018404231981
# 16 (35, 18) -56.71653661712608
# 17 (35, 16) -54.190917853994335
# 18 (35, 15) -52.930018950135704
# 19 (35, 14) -51.672745026858614
# 20 (35, 13) -50.41940459608801
# 21 (35, 12) -51.65156214144115
# 22 (35, 11) -63.743098233645696
# 23 (35, 10) -67.650436918178
# 24 (35, 9) -70.88681261112288
# 25 (35, 8) -72.09373320929404
# 26 (35, 7) -73.69396799311679
# 27 (35, 6) -72.72427845260793
# 28 (35, 5) -74.59872925840416
# 29 (35, 4) -89.2918437580275
# 30 (35, 3) -94.57927420089712
# 31 (35, 2) -104.51351335006652

# %%
plt.plot(data['Y'], label = "Ishigami Function")
plt.plot(Phi_hat@a_hat, label = "AFVB-PCE")
plt.legend();

# %%
active_cols
# Out:
# array([  0,   1,   3,   5,  19,  30,  39,  44,  45, 109, 111, 153, 154])

# %%
#add coefficients to mod using mod._coeffs = ...

# %% [markdown]
# ### Using Test Data

# %%
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(99)
Test_data={'Xi':np.random.uniform(-1, 1, size=(100,d))}

z_1 = Test_data['Xi'][:,0]
z_2 = Test_data['Xi'][:,1]
z_3 = Test_data['Xi'][:,2]

Test_data['Y'] = np.c_[np.sin(np.pi*z_1) + 7*(np.sin(np.pi*z_2))**2 + 0.1*(np.pi*z_3)**4*np.sin(np.pi*z_1)]

# %%
Phi_test_full = basis(Test_data['Xi'])
Phi_test = basis(Test_data['Xi'])[:,active_cols]

# %%
print("RMSE - Training Data:", mean_squared_error(data['Y'], Phi_full@a_full))
print("RMSE - Training Data:", mean_squared_error(data['Y'], Phi_hat@a_hat))
# Out:
# RMSE - Training Data: 0.008539044079158509
# RMSE - Training Data: 0.009639290482113622

# %%
a_hat.shape
# Out:
# (13, 1)

# %%
print("RMSE - Testing Data:", mean_squared_error(Test_data['Y'], Phi_test_full@a_full))
print("RMSE - Testing Data:", mean_squared_error(Test_data['Y'], Phi_test@a_hat))
# Out:
# RMSE - Testing Data: 6.001902568086845
# RMSE - Testing Data: 6.009963852794775

# %%
#### The behaviour of this one should be similar to the second problem
#### So the RMSE should reduce when we increase N or p

# %% [markdown]
# ## PC-VRVM (Tsilifis) - Ishigami Function

# %%
################
#### Inputs ####
################
N = 1000 # N --> number of samples
d = 3  # d --> number of random variables
p = 10  # p --> degree of PCE polynomial
n = int(math.factorial(d + p)/(math.factorial(d)*math.factorial(p))) # n --> Number of terms in the PCE expansion

# %%
##########################################################################################
#### Generate N samples for d random variables and compute the responses at N samples ####
##########################################################################################
# ---- Setting the example: Coeffs, data and chaos model ------

sys.path.append('..')

np.random.seed(9)

data={'xi':np.random.uniform(-1,1,size=(N,d))}
data['y'] = np.sin(np.pi*data['xi'][:,0]) + 7*(np.sin(np.pi*data['xi'][:,1]))**2 + 0.1*(np.pi*data['xi'][:,2])**4*np.sin(np.pi*data['xi'][:,0])

# %%
# --- RUN RELEVANCE VECTOR MACHINE FIT
chaos = ChaosModel(d, p, basis, (n,d))

# The success probability for the Bernoulli dinsities is a/(a+b)
# Choices of these parameters allow controling the level of sparsity in the model
a_0 = 0.2
b_0 = 1.0

params = {'omega' : [1e-6, 1e-6], 'tau': [1e-6, 1e-6], 'pi': [ a_0, b_0 ]}

V0 = SparseVariationalOptimizer(chaos, data, params)

c_sol, omega_sol, tau_sol, z_sol, pi_sol, iters, elbo  = V0.optimize(tol = .0001)

df_c = pd.DataFrame(c_sol, columns=['mu','rho'])
df_o = pd.DataFrame(omega_sol, columns=['kappa','lambda'])
df_t = pd.DataFrame(tau_sol, columns=['m','n'])
df_z = pd.DataFrame(z_sol, columns=['pi'])
df_p = pd.DataFrame(pi_sol, columns=['alpha','beta'])
df_elbo = pd.DataFrame(elbo, columns = ['elbo'])

import matplotlib.pyplot as plt 
fig = plt.figure(figsize = (10, 5))
ax1 = fig.add_subplot(121)
ax1.plot(c_sol[:,0], 'x')
ax1.set_xscale('log')
ax2 = fig.add_subplot(122)
ax2.plot(z_sol, 'o')
ax2.set_xscale('log')
plt.show()
# Out:
# 1.1855627420795019
# Iters = 0          Relative error : 14010.248354667236
# 5.405150252414921
# 4.11723331129201
# 3.2647074818730335
# 1.0404821187943512
# 0.9800475334300085
# 1.7462557385461217
# 0.2046482439191557
# 0.0650592810050945
# 0.17737712009537887
# 0.800901766747188
# Iters = 10          Relative error : 94855195.64694463
# 2.5365106084352824
# 2.435075818479376
# 2.419371136501095
# 2.126619272837271
# 1.8803707238018355
# 1.8316930953209436
# 1.8989370630183373
# 1.938113037283685
# 1.6518743233371112
# 1.376917927762399
# Iters = 20          Relative error : 10747092.715286165
# 1.040953917063817
# 0.5407242590931816
# 0.3679559586921002
# 0.30536234948282015
# 0.39144952054233073
# 0.44477077586782343
# 0.31320081405934985
# 0.22117444191546554
# 0.18559632177559138
# 0.21796634954662863
# Iters = 30          Relative error : 2253433.5667237276
# 0.34993448982669406
# 0.5087723114407794
# 0.42485407353335347
# 0.1798848252036862
# 0.05518185227034422
# 0.01952047614260266
# 0.009521130242980291
# 0.005894105336984978
# 0.004108323863682983
# 0.003025086894474782
# Iters = 40          Relative error : 29281.431066445508
# 0.0022934392651805524
# 0.0017727300141956448
# 0.0013913874046664887
# 0.0011066200134024484
# 0.000890538561776566
# 0.0007242020558066997
# 0.0005944651210327834
# 0.0004920598530091524
# 0.0004103535555657345
# 0.0003445271215980483
# Iters = 50          Relative error : 5009.511537612614
# 0.00029102706177042137
# 0.000247196755644552
# 0.00021102510193315993
# 0.00018097248185711123
# 0.00015584825769110466
# 0.00013472317483831375
# 0.00011686584713288539
# 0.00010169610473553803
# 8.875036255773239e-05
# 7.765564119921464e-05
# Iters = 60          Relative error : 1440.2579937720673
# 6.810990510075499e-05
# 5.986705855320906e-05
# 5.272540714429397e-05
# 4.651871616800918e-05
# 4.11092432273108e-05
# 3.638226919377985e-05
# 3.22417777098849e-05
# 2.8607033300431794e-05
# 2.5409841569512537e-05
# 2.2592360004125567e-05
# Iters = 70          Relative error : 467.5579622115915
# 2.0105322114716273e-05
# 1.790661116984893e-05
# 1.5960085711697047e-05
# 1.4234629972520452e-05
# 1.2703367239907948e-05
# 1.1343010839937051e-05
# 1.0133330142991781e-05
# 9.056700299936438e-06
# 8.097731125644714e-06
# 7.242951092223393e-06
# Iters = 80          Relative error : 156.64706021019552
# 6.480545600595633e-06
# 5.800130224997702e-06
# 5.192561928879513e-06
# 4.6497787664634416e-06
# 4.164658477634475e-06
# 3.7309029394805293e-06
# 3.342932288319389e-06
# 2.9958008695984972e-06
# 2.685116264444787e-06
# 2.4069775079738065e-06
# Iters = 90          Relative error : 52.954242481709464
# 2.1579149915851303e-06
# 1.934838195438715e-06
# 1.7349969709812285e-06
# 1.5559385033725448e-06
# 1.3954742570376766e-06
# 1.2516524989791833e-06
# 1.1227293512661163e-06
# 1.0071475102790828e-06
# 9.035153425429598e-07
# 8.105865418883695e-07
# Iters = 100          Relative error : 17.950744503414533
# 7.272496276300444e-07
# ----- Iterating only on sparse terms -----
# 6.614199747900784e-07
# ----- Iterating only on sparse terms -----
# 5.927481936396362e-07
# ----- Iterating only on sparse terms -----
# 5.31499061651175e-07
# ----- Iterating only on sparse terms -----
# 4.7669750102841135e-07
# ----- Iterating only on sparse terms -----
# 4.275896543504132e-07
# ----- Iterating only on sparse terms -----
# 3.835638722193835e-07
# ----- Iterating only on sparse terms -----
# 3.440856204406373e-07
# ----- Iterating only on sparse terms -----
# 3.0868204703438096e-07
# ----- Iterating only on sparse terms -----
# 2.7692880166796385e-07
# ----- Iterating only on sparse terms -----
# Iters = 110          Relative error : 6.075833110902809
# 2.484480958742097e-07
# ----- Iterating only on sparse terms -----
# 2.2290146972636649e-07
# ----- Iterating only on sparse terms -----
# 1.9998594780190615e-07
# ----- Iterating only on sparse terms -----
# 1.794289516965364e-07
# ----- Iterating only on sparse terms -----
# 1.6098754684890082e-07
# ----- Iterating only on sparse terms -----
# 1.4444334084373622e-07
# ----- Iterating only on sparse terms -----
# 1.2960101969383686e-07
# ----- Iterating only on sparse terms -----
# 1.1628503671090584e-07
# ----- Iterating only on sparse terms -----
# 1.0433815589294682e-07
# ----- Iterating only on sparse terms -----
# 9.361973951627078e-08
# ----- Iterating only on sparse terms -----
# Iters = 120          Relative error : 2.056437203541352
# 8.400272832886913e-08
# ----- Iterating only on sparse terms -----
# 7.537414603575598e-08
# ----- Iterating only on sparse terms -----
# 6.763218607375165e-08
# ----- Iterating only on sparse terms -----
# 6.068624713861936e-08
# ----- Iterating only on sparse terms -----
# 5.445404127613074e-08
# ----- Iterating only on sparse terms -----
# 4.886152993321957e-08
# ----- Iterating only on sparse terms -----
# 4.38438689798204e-08
# ----- Iterating only on sparse terms -----
# 3.934134440441994e-08
# ----- Iterating only on sparse terms -----
# 3.530152525854646e-08
# ----- Iterating only on sparse terms -----
# 3.167652096180973e-08
# ----- Iterating only on sparse terms -----
# Iters = 130          Relative error : 0.6960967413524796
# 2.8423770004337712e-08
# ----- Iterating only on sparse terms -----
# 2.5505620726562483e-08
# ----- Iterating only on sparse terms -----
# 2.288651756998661e-08
# ----- Iterating only on sparse terms -----
# 2.053653958000723e-08
# ----- Iterating only on sparse terms -----
# 1.84279755899297e-08
# ----- Iterating only on sparse terms -----
# 1.65360773962675e-08
# ----- Iterating only on sparse terms -----
# 1.4838406059425324e-08
# ----- Iterating only on sparse terms -----
# 1.3314817692844372e-08
# ----- Iterating only on sparse terms -----
# 1.19480247917636e-08
# ----- Iterating only on sparse terms -----
# 1.0720867749114404e-08
# ----- Iterating only on sparse terms -----
# Iters = 140          Relative error : 0.23563417106862286
# 9.620301000268228e-09
# ----- Iterating only on sparse terms -----
# 8.632810022390913e-09
# ----- Iterating only on sparse terms -----
# 7.746230323846248e-09
# ----- Iterating only on sparse terms -----
# 6.951246689368418e-09
# ----- Iterating only on sparse terms -----
# 6.237613092707761e-09
# ----- Iterating only on sparse terms -----
# 5.597016183855885e-09
# ----- Iterating only on sparse terms -----
# 5.022492644002341e-09
# ----- Iterating only on sparse terms -----
# 4.506809148097091e-09
# ----- Iterating only on sparse terms -----
# 4.0442458271172654e-09
# ----- Iterating only on sparse terms -----
# 3.6291680771682877e-09
# ----- Iterating only on sparse terms -----
# Iters = 150          Relative error : 0.07976517878671306
# 3.256509728544188e-09
# ----- Iterating only on sparse terms -----
# 2.922234898505849e-09
# ----- Iterating only on sparse terms -----
# 2.6219595383736305e-09
# ----- Iterating only on sparse terms -----
# 2.3529125314780686e-09
# ----- Iterating only on sparse terms -----
# 2.1115624804224353e-09
# ----- Iterating only on sparse terms -----
# 1.8945840452033735e-09
# ----- Iterating only on sparse terms -----
# 1.7000800767164037e-09
# ----- Iterating only on sparse terms -----
# 1.5255992025231535e-09
# ----- Iterating only on sparse terms -----
# 1.3690666378352034e-09
# ----- Iterating only on sparse terms -----
# 1.2283791761547036e-09
# ----- Iterating only on sparse terms -----
# Iters = 160          Relative error : 0.02700145528478409
# 1.1025775847883779e-09
# ----- Iterating only on sparse terms -----
# 9.888054819384706e-10
# ----- Iterating only on sparse terms -----
# 8.877805157680996e-10
# ----- Iterating only on sparse terms -----
# 7.964118253767083e-10
# ----- Iterating only on sparse terms -----
# 7.147633596105152e-10
# ----- Iterating only on sparse terms -----
# 6.413500841517816e-10
# ----- Iterating only on sparse terms -----
# 5.753548748543835e-10
# ----- Iterating only on sparse terms -----
# 5.164153549230832e-10
# ----- Iterating only on sparse terms -----
# 4.6352965910045896e-10
# ----- Iterating only on sparse terms -----
# 4.1604408806961146e-10
# ----- Iterating only on sparse terms -----
# Iters = 170          Relative error : 0.009140733862027258
# 3.729709874278342e-10
# ----- Iterating only on sparse terms -----
# 3.348219479448744e-10
# ----- Iterating only on sparse terms -----
# 3.0038194154258235e-10
# ----- Iterating only on sparse terms -----
# 2.6977176048603724e-10
# ----- Iterating only on sparse terms -----
# 2.4228086203947896e-10
# ----- Iterating only on sparse terms -----
# 2.1662316385118174e-10
# ----- Iterating only on sparse terms -----
# 1.9469581502562505e-10
# ----- Iterating only on sparse terms -----
# 1.751487843648647e-10
# ----- Iterating only on sparse terms -----
# 1.567812546454661e-10
# ----- Iterating only on sparse terms -----
# 1.4063772368899663e-10
# ----- Iterating only on sparse terms -----
# Iters = 180          Relative error : 0.003093515869104697
# 1.2644107982850983e-10
# ----- Iterating only on sparse terms -----
# 1.1324630122544477e-10
# ----- Iterating only on sparse terms -----
# 1.0187761745328316e-10
# ----- Iterating only on sparse terms -----
# 9.104184073294164e-11
# ----- Iterating only on sparse terms -----
# 8.173373089448432e-11
# ----- Iterating only on sparse terms -----
# 7.363354370681918e-11
# ----- Iterating only on sparse terms -----
# 6.59809984426829e-11
# ----- Iterating only on sparse terms -----
# 5.918820988881635e-11
# ----- Iterating only on sparse terms -----
# 5.324807261786191e-11
# ----- Iterating only on sparse terms -----
# 4.764189043271472e-11
# ----- Iterating only on sparse terms -----
# Iters = 190          Relative error : 0.0010482036047052823
# 4.256150987203e-11
# ----- Iterating only on sparse terms -----
# 3.8397729440475814e-11
# ----- Iterating only on sparse terms -----
# 3.455369324001367e-11
# ----- Iterating only on sparse terms -----
# 3.090860900556436e-11
# ----- Iterating only on sparse terms -----
# 2.773958840407431e-11
# ----- Iterating only on sparse terms -----
# 2.4925839170464315e-11
# ----- Iterating only on sparse terms -----
# 2.226840933872154e-11
# ----- Iterating only on sparse terms -----
# 2.0122570276726037e-11
# ----- Iterating only on sparse terms -----
# 1.800515292416094e-11
# ----- Iterating only on sparse terms -----
# 1.6214585230045486e-11
# ----- Iterating only on sparse terms -----
# Iters = 200          Relative error : 0.0003546744638515192
# 1.439559582649963e-11
# ----- Iterating only on sparse terms -----
# 1.2953194072906626e-11
# ----- Iterating only on sparse terms -----
# 1.1638690011750441e-11
# ----- Iterating only on sparse terms -----
# 1.0381029369455064e-11
# ----- Iterating only on sparse terms -----
# 9.450218385609332e-12
# ----- Iterating only on sparse terms -----
# 8.498091119690798e-12
# ----- Iterating only on sparse terms -----
# 7.432277016050648e-12
# ----- Iterating only on sparse terms -----
# 6.913580818945775e-12
# ----- Iterating only on sparse terms -----
# 6.0467186813184526e-12
# ----- Iterating only on sparse terms -----
# 5.314859663485549e-12
# ----- Iterating only on sparse terms -----
# Iters = 210          Relative error : 0.00012013935294684068
# 4.860112312599085e-12
# ----- Iterating only on sparse terms -----
# 4.483524662646232e-12
# ----- Iterating only on sparse terms -----
# Total number of iterations : 213

# %%
active_indices = np.array(range(0,n))[z_sol>0.01]

# %%
chaos._coeffs = c_sol[:,0]

# %%
plt.plot(data['y'][0:35])
plt.plot(chaos.eval(data['xi'], active_indices)[0:35]);

# %% [markdown]
# ### Using Test Data

# %%
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(99)
Test_data={'xi':np.random.uniform(-1, 1, size=(100,d))}

z_1 = Test_data['xi'][:,0]
z_2 = Test_data['xi'][:,1]
z_3 = Test_data['xi'][:,2]

Test_data['y'] = np.c_[np.sin(np.pi*z_1) + 7*(np.sin(np.pi*z_2))**2 + 0.1*(np.pi*z_3)**4*np.sin(np.pi*z_1)]

# %%
print("RMSE - Training Data:", mean_squared_error(data['y'], chaos.eval(data['xi'])))
print("RMSE - Training Data:", mean_squared_error(data['y'], chaos.eval(data['xi'], active_indices)))
# Out:
# RMSE - Training Data: 1.7327292350847173e-05
# RMSE - Training Data: 1.912114409535604e-05

# %%
print("RMSE - Testing Data:", mean_squared_error(Test_data['y'], chaos.eval(Test_data['xi'])))
print("RMSE - Testing Data:", mean_squared_error(Test_data['y'], chaos.eval(Test_data['xi'], active_indices)))
# Out:
# RMSE - Testing Data: 4.500023609255545e-05
# RMSE - Testing Data: 4.5915112394470694e-05
